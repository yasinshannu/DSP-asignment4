# %%
import folium

my_map1=folium.Map(location = [13.57932925607217, 78.50009283384993],zoom_start = 12)
my_map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
my_map2=folium.Map(location = [13.5560, 78.5010],zoom_start = 12)

folium.CircleMarker(location = [13.5560, 78.5010],radius = 50, popup = ' FRI ').add_to(my_map2)
my_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
my_map3=folium.Map(location = [13.5560, 78.5010],zoom_start = 15)

folium.Marker(location = [13.5560, 78.5010],popup = ' MADANAPALLI ').add_to(my_map3)
my_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
my_map4=folium.Map(location = [13.5560, 78.5010],zoom_start = 7)

folium.Marker(location = [16.7850, 80.8488],popup = ' NUZIVIDU ').add_to(my_map4)

folium.Marker(location = [13.5560, 78.5010],popup = ' Madanapalli ').add_to(my_map4)

 
folium.PolyLine(locations = [(16.7850, 80.8488), (13.5560, 78.5010)],line_opacity = 0.5).add_to(my_map4)

my_map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
my_map5=folium.Map(location = [13.5560, 78.5010],zoom_start = 7)

folium.Marker(location = [16.7850, 80.8488],popup = ' NUZIVIDU ',icon=folium.Icon(color='green',prefix='fa',icon='flash')).add_to(my_map5)

folium.Marker(location = [16.5062, 80.6480],popup = ' VIJAYAWADA ',icon=folium.Icon(color='purple',prefix='fa',icon='send')).add_to(my_map5)

folium.Marker(location = [14.4673, 78.8242],popup = ' KADAPA ',icon=folium.Icon(color='red',prefix='fa',icon='fire')).add_to(my_map5)

folium.Marker(location = [14.7309, 79.0589],popup = ' BADVEL ',icon=folium.Icon(color='pink',prefix='fa',icon='camera')).add_to(my_map5)

folium.Marker(location = [16.0568, 79.7453],popup = ' VINUKONDA ',icon=folium.Icon(color='cadetblue',prefix='fa',icon='apple')).add_to(my_map5)

folium.Marker(location = [15.7362, 79.2691],popup = ' MARKAPUR ',icon=folium.Icon(color='gray',prefix='fa',icon='music')).add_to(my_map5)

folium.Marker(location = [14.0586, 78.7519],popup = ' RAYACHOTY ',icon=folium.Icon(color='green',prefix='fa',icon='envelope')).add_to(my_map5)

folium.Marker(location = [16.3067, 80.4365],popup = ' GUNTUR ',icon=folium.Icon(color='beige',prefix='fa',icon='star')).add_to(my_map5)

folium.Marker(location = [15.5057, 80.0499],popup = ' ONGOLE ',icon=folium.Icon(color='red',prefix='fa',icon='anchor')).add_to(my_map5)

folium.Marker(location = [14.9132, 79.9930],popup = ' KAVALI ',icon=folium.Icon(color='green',prefix='fa',icon='thumbs-up')).add_to(my_map5)

folium.Marker(location = [14.4426, 79.9865],popup = ' NELLORE ',icon=folium.Icon(color='orange',icon='off')).add_to(my_map5)

folium.Marker(location = [13.6288, 79.4192],popup = ' TIRUPATI ',icon=folium.Icon(color='black',icon='cloud')).add_to(my_map5)

folium.Marker(location = [13.2172, 79.1003],popup = ' CHITTOOR ',icon=folium.Icon(color='black',icon='heart-empty')).add_to(my_map5)

folium.Marker(location = [13.5560, 78.5010],popup = ' MADANAPALLI ',icon=folium.Icon(color='red',icon='home')).add_to(my_map5)



